# %%
setwd("C:/Users/ambalika.smiti/Desktop/Ambalika/OLA OFFICE WORK/Feedbacks_new")

# %%
data=read.csv("Driver_Profile_for_Quality_Analysis.csv")
data=data[,-c(20:23)]

# %%
nrow(data)
ncol(data)
head(data)

# %%
ok=complete.cases(data)
sum(!ok)

# %%
data.complete=data[ok,]

# %%
nrow(data.complete)
head(data.complete)

# %%
attach(data.complete)
head(data.complete)
# Out:
# The following objects are masked from data.complete (pos = 3):
#
#     BAD_GUYS, Car, CQ, CQ12, D_Age, D_AoP, D_edu, D_Marital, DL_number,
#     DP, DP12, Driver_city, Driver_sugar_id, OLA_Score_45, Rides, Rtag,
#     UB, UB12, X12Rating
#
# The following objects are masked from data.complete (pos = 4):
#
#     BAD_GUYS, Car, CQ, CQ12, D_Age, D_AoP, D_edu, D_Marital, DL_number,
#     DP, DP12, Driver_city, Driver_sugar_id, OLA_Score_45, Rides, Rtag,
#     UB, UB12, X12Rating
#    Driver_sugar_id                      DL_number       Driver_city Car
# 3  55f4369a-e03e-486f-bcfd-4b4bde9b0002 TN0220060024403 Chennai     TN11U8082
# 4  fb945193-39e2-40bd-ab7b-1836e1d7da9d MH1320100024711 Pune        MH14GD2950
# 7  9cbf74b6-939a-415c-aa78-6799e53a8aac TN1320150004968 Chennai     TN22DD9097
# 8  b532daed-4f33-4df4-bb72-b7a2460afbd4 TN0920120002346 Chennai     TN09CK5431
# 10 ba569354-5f6e-41ec-8b13-7aac0208ca44 WB0119860352444 Kolkata     WB04G3734
# 14 bad0cac5-a70e-47b1-985f-864bdec12bd1 UP7220150006197 Delhi       DL1YE3835
#    BAD_GUYS OLA_Score_45 Rides X12Rating UB   CQ   DP   UB12 CQ12 DP12 Rtag
# 3  0        8.52         191.0  3.3      0.33 0.33 1.00 0.00 0.00 0.33 R1
# 4  0        9.00         190.7  4.7      3.33 0.33 7.33 3.00 0.33 1.00 R1
# 7  0        9.23         187.0  1.7      1.67 1.00 1.33 0.67 0.00 0.00 R1
# 8  0        9.03         187.0  5.0      2.67 1.00 1.33 1.00 0.00 0.67 R1
# 10 0        9.17         185.7 11.0      4.67 2.33 2.33 3.33 1.33 0.00 R1
# 14 0        8.51         181.7  3.7      5.33 1.33 1.00 2.33 0.33 0.00 R1
#    D_AoP D_Age D_Marital D_edu
# 3  482   33    Married   SSC/HSC(10thpass)
# 4  112   30    Single    SSC/HSC(10thpass)
# 7  421   30    Married   SSC/HSCbutnotgraduate(12thpass)
# 8  94    25    Single    SSC/HSC(10thpass)
# 10 694   52    Married   School5-9years
# 14 302   24    Married   SSC/HSC(10thpass)

# %%
hist(Rides,breaks=100)
# Out:
# Plot with title "Histogram of Rides"

# %%
hist(OLA_Score_45,breaks=5,labe)
# Out:
# Plot with title "Histogram of OLA_Score_45"

# %%
hist(X12Rating)
# Out:
# Plot with title "Histogram of X12Rating"

# %%
plot(UB,CQ)
# Out:
# plot without title

# %%
plot(UB/Rides,DP/Rides)
# Out:
# plot without title

# %%
names(data.complete)
# Out:
#  [1] "Driver_sugar_id" "DL_number"       "Driver_city"     "Car"
#  [5] "BAD_GUYS"        "OLA_Score_45"    "Rides"           "X12Rating"
#  [9] "UB"              "CQ"              "DP"              "UB12"
# [13] "CQ12"            "DP12"            "Rtag"            "D_AoP"
# [17] "D_Age"           "D_Marital"       "D_edu"

# %%
plot(D_edu,UB/Rides)
# Out:
# plot without title
